# %%
# 主方法

import CEEMDAN as cl

def run_respective_example():
    print('##################################')
    
    # (1) 声明路径
    print("\n(1) Declare a path for saving files:")
    print("-------------------------------")
    series = cl.declare_path()
    
    # (2) CEEMDAN 分解
    print("\n(2) CEEMDAN decompose:")
    print("-------------------------------")
    cl.declare_vars(mode='ceemdan')
    imfs = cl.emd_decom()
    
    # (3) 样本熵
    print("\n(3) Sample Entropy:")
    print("-------------------------------")
    cl.sample_entropy()
    
    # (4) 整合 IMFs
    print("\n(4) Integrating IMFs:")
    print("-------------------------------")
    cl.integrate(inte_form=[[0],[1,2,3,4],[5,6,7,8]])  # form='144'
    
    # (5) 分别 LSTM 预测
    print("\n(5) Forecast with Respective LSTM:")
    print("-------------------------------")
    cl.declare_vars(mode='ceemdan_se', form='144')  # 声明预测变量
    cl.Respective_LSTM()  # 使用 LSTM 预测

if __name__ == '__main__':
    run_respective_example()
# Out:
# Importing...##################################
#
# (1) Declare a path for saving files:
# -------------------------------
# Saving path: D:\vscode\code\work\
# Load sample dataset: guanzhou.csv
# (2) CEEMDAN decompose:
# -------------------------------
# ##################################
# Global Variables
# ##################################
# MODE:CEEMDAN
# FORM:
# DATE_BACK:30
# PERIODS:100
# EPOCHS:100
# PATIENCE:10
# CEEMDAN decomposition is running.
# CEEMDAN finished, check the dataset:  D:\vscode\code\work\ceemdan_data.csv
#
# (3) Sample Entropy:
# -------------------------------
# Sample entropy of CEEMDAN is running.
# (4) Integrating IMFs:
# -------------------------------
# The Integrating Form: 144
# Integration finished, check the dataset:  D:\vscode\code\work\ceemdan_se144_data.csv
#
# (5) Forecast with Respective LSTM:
# -------------------------------
# ##################################
# Global Variables
# ##################################
# MODE:CEEMDAN_SE
# FORM:144
# DATE_BACK:30
# PERIODS:100
# EPOCHS:100
# PATIENCE:10
# ==============================================================================================
# This is Respective LSTM Forecasting running...
# ==============================================================================================
# Part of Inputting dataset:
#        co-imf0    co-imf1    co-imf2
# 0     0.152005  -9.800144  69.818139
# 1     0.473344 -10.298473  69.825130
# 2    -0.447466  -9.375101  69.822567
# 3     0.312630  -7.122982  69.810351
# 4     0.296391  -5.084772  69.788381
# ...        ...        ...        ...
# 2718  0.290500   0.290734  39.048766
# 2719 -0.160787   0.544649  39.046138
# 2720 -0.145614   0.529535  39.046079
# 2721  0.056392   0.325022  39.048586
# 2722  0.005091   0.371281  39.053629
#
# [2723 rows x 3 columns]
# ==============================================================================================
# CEEMDAN_SE--IMF0
# ==============================================================================================
#
# Input Shape: (30,1)
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 128)           66560
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 30, 64)            49408
#
#  dropout_1 (Dropout)         (None, 30, 64)            0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 128,417
# Trainable params: 128,417
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 4ms/step
# ##################################
# Model Evaluation with scale of 0 to 1
# ##################################
# R2: 5.334122860933821e-05
# RMSE: 0.06510694686479189
# MAE: 0.05430049282707351
# MAPE: 11.329405259479417
# ==============================================================================================
# CEEMDAN_SE--IMF1
# ==============================================================================================
#
# Input Shape: (30,1)
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 128)           66560
#
#  dropout_3 (Dropout)         (None, 30, 128)           0
#
#  lstm_4 (LSTM)               (None, 30, 64)            49408
#
#  dropout_4 (Dropout)         (None, 30, 64)            0
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 128,417
# Trainable params: 128,417
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 4ms/step
# ##################################
# Model Evaluation with scale of 0 to 1
# ##################################
# R2: 0.9176724122541269
# RMSE: 0.012138216380059635
# MAE: 0.009312752494181079
# MAPE: 2.4765349921981725
# ==============================================================================================
# CEEMDAN_SE--IMF2
# ==============================================================================================
#
# Input Shape: (30,1)
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 30, 128)           66560
#
#  dropout_6 (Dropout)         (None, 30, 128)           0
#
#  lstm_7 (LSTM)               (None, 30, 64)            49408
#
#  dropout_7 (Dropout)         (None, 30, 64)            0
#
#  lstm_8 (LSTM)               (None, 32)                12416
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 128,417
# Trainable params: 128,417
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 4ms/step
# ##################################
# Model Evaluation with scale of 0 to 1
# ##################################
# R2: 0.9693905104698455
# RMSE: 0.0037862728762100614
# MAE: 0.0033468829139670898
# MAPE: 0.8976140026562319
# ##################################
# Model Evaluation with scale of input df
# ##################################
# R2: 0.8826020606979692
# RMSE: 0.8682410638613762
# MAE: 0.678794828033447
# MAPE: 1.799715445832599
# Running time: 274.465s
# Respective LSTM Forecasting finished, check the logs D:\vscode\code\work\subset\respective_ceemdan_se144_log.csv
